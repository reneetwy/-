# %% [markdown]
# # Team Mission: Bomb Game 💣
#
# Imagine you are a bomb-disposal expert and you are on a mission to remove the bomb reported in the public. 🕵🏻‍♂️
#
# ### Your Goal:
# There are 5 lines of 5 different colors and you can cut 1 each time.
# If you can find it within 3 guesses, the bomb will be removed and you win;
# If you lose all 3 chances, the bomb will explode!💥

# %% [markdown]
# ## Task 0: Run the following block

# %%
Find_Bomb= '''
／￣￣￣￣＼　
|  ー  ー \　  ／￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣＼
|   ◉　◉  |   |   Found a BOMB 💣!                    |
\  💧 ▱💧 /   ∠     Please remove it immediately ！！！/
 ＼　　  イ　   \                                     /                       
／　　　  \      ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣
|　|　　 ||
'''

Bomb_remove = '''
／￣￣￣￣＼　
|  ー　ー \　  ／￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣＼
|   ◉　◉  |   | Well done, you remove the bomb! |
\     v  /   ∠             ！！！！              /
 ＼　　 イ　    \                               /                             
／　　   \       ￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣￣
|　|　  ||
'''

Bomb_explode = "💥 Everything is blown out..."

# %% [markdown]
# ## Task 1: Create RemoveBomb Function
#
# ### 💎Keys: variable, assignment, while loop, string, print(), if statement, function, list, import
#
# 1. Import package called random (the line triggered the bomb to explode is randomly picked🔮)
#
# 2. Create a list named **lines** includes 5 types of lines - Green, Blue, Red, Yello, Grey (the elements in the list are ** string** 🤓)
#  ```python
#      #How to create a list:
#      list = ["a", "b", "c", "d", "e"]
# ```
#
# 3. Create a function:
#       - Function name is **RemoveBomb**.
#       - Has **no parameter**.
#
# 4. Assigning values to 4️⃣ variables **inside the function**:
#       - Create a variable **line_index** with **random.randint(0,4)**.
#       - Create a variable **count** with the value **0**.
#       - Create a variable **remove_success** with a boolean value **False**.
#       - Create a variable **chosen_line** using what you learnt about list and index.
#
# ### 🗝 What is a chosen line?
#    - It's the line that triggered the bomb to explore. It is generated randomly from the list **lines**
#    - You can get the value of the element using its index.
#  ```python
#      #Hint: How to create a list and get the value of an element:
#      list = ["a", "b", "c", "d", "e"]
#      list[0] = "a"
# ```
#
# 5. Write an **while loop inside the function**:
#       - The **while loop** will keep running when the variable **count < 3**.
#
# 6. **Inside** the **while loop**:
#       - Assigning a variable **guess** with input() and ask "Which line do you want to cut?"
#       - Assign the variable **count** with an operation **count+1**
#       - Write an **if statement** inside the **while loop**:
#
#         a. If **guess** is equal to the **chosen line**.
#            - we will change the variable **remove_success** into True(we use boolean value to indicate if the bomb is removed or not).
#            - start a new line and use **break** keyword to stop the **while loop**.
#
#        b. else:
#            - print the text "You lose a chance. Try again!"
#
# 7. Write another if statement **outside** the **while loop** but **inside the function**:
#       - The **if statement** will check if the variable **removebomb** is equal to **True**.
#       - If the variable **removebomb** is equal to **True**:
#            - print the variable **Bomb_remove**.
#       - else:
#            - print the variable **Bomb_explode**.
#
# 8. Test the game!
#       - print(Find_Bomb)
#       - call the function
#  ```python
#     #Hint: How to call a function:
#       RemoveBomb()
#  ```

# %% [markdown]
# ### 🗝Hints:
#
# - Example for creating function:
#     ```python
#         def function_name():
#     ```
# - Example for assigning value to variable:
#
#   ```python
#         variable_name = "some value"
#   ```
#
# - Example for **if statement**:
#     ```python
#         if 1>3:
#             print("1 is bigger than 3!")
#         else:
#             print("1 is not bigger than 3!")
#
#     ```
# - Example of checking if a variable **variable_name** is equal to a string "You bad bad.".
#     ```python
#         if variable_name == "You bad bad.":
#             print(variable_name)
#         else:
#             print("You still bad bad.")
#     ```
# - Example of how to use **break** keyword?
#     ```python
#         while(True):
#             break
#     ```
# - Example of how to print a variable.
#     ```python
#         I_Am_A_Variable = "Nice to meet you~"
#         print(I_Am_A_Variable)
