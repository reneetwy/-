# %% [markdown]
# # Task 1🤠
# ### 1. Create the following **variables** to store your **friend's information**:
# ```
#     friend_name
#     friend_age
#     friend_grade
# ```
# ### 2. **Assign** value to the variables with the **information of your friend**
# ### 3. **Do the same thing** to store **your information** in the following variables:
# ```
#     my_name
#     my_age
#     my_grade
# ```
# ### 4. Print all information.
# 🔑 Hint:
# ```python
# print()
# ```

# %% [markdown]
# # Task 2✨
# ## Imgaine you are Head of School and you have to manage the student database. There are 1000 students, isn't there too much work in the Task 1 to create so many variables for each student? 🤔
#
# ## Luckily, we can use **class**. 😀
#
# ## Class is like a box🗃️ that can collect related variables together.
# - Let's create a class called "Student" to store student's information.
#
# ### Student class👨🏻‍💻:
#
#
#
# ```
#         1.Create a class named Student.
#
#         2.Create def __init__ function with parameters such as name, age, grade to store information.
#
#
#         3.Create variables and assign values in this function:
#             self.name = name
#             self.age = age
#             self.grade = grade
# ```
#
#
# ## Example of a class:
# ```python
#     class Example:
#
#         def __init__(self,parameter_1,parameter_2...):
#             self.variable_1 = parameter_1
#             self.variable_2 = parameter_2
#             ...
# ```

# %% [markdown]
# # Task 3🌅
#
# ## A new student named "Steve" is joining and you are adding him to the student database. He's 12 year old and he's at G6.
#
# ## GOAL :  Create an instance called 'new_student' for the class 'Student'.
#
# ```python
#     #example of an instance:
#     example_1 = Example(argument_1,argument_2...)
# ```
#
# ### What is an instance?
# - The **'example_1'** is an instance of class 'Example'.
# - An instance can **carry multiple variables** of a class.
#
#
#
# "

# %% [markdown]
# # Task 4💈
#
# ## GOAL: Try to print every variables inside the instance 'new_student'.
#
# 🔑Hint: How to access the variables inside an instance?
#
# If we have an instance called **'example_1'**, and it has a variable called **'variable_1'**.
#
#   ```python
#     #example of printing an variable in an instance:
#     print(example_1.variable_1)
#   ```

# %% [markdown]
# # Task 5 📚
# ## Class is not only a great way to manage student database, but also books! 🤓
# ### In this task we will build a library counter together!
# - As we have learnt, a class can have a function **def \_\_init\_\_** inside. But actually we can create many functions in a class!
# ```python
#     #An example of multiple functions in a class
#     class Example:
#         def __init__(self):
#             self.variable_1 = "We can change a variable without a corresponding parameter."
#
#         def printText(self):
#             print(self.variable_1)
# ```
# - Warning: **Indentation** is important to seperate different functions.
#
# - To call a function inside the instance, we aslo use **'.'**.
# ```python
#     example = Example()
#     example.printText()
# ```
#
#
# ### Milestone 1: Create a class named 'Book'
# ### Inside the class, create 3 functions:
# #### A **🗝️'\_\_init\_\_' function**:
# 1. With the parameters **'(self)'**.
# 2. With a variable called **'self.borrowed_by'** and assign it with **"nobody"**.
#
# #### A **📚function** called **'BorrowBook'**:
# 1. With the parameters **'(self,studentName)'**.
# 2. Read the **variable 'self.borrowed_by'**:
# ```
#     If the variable 'self.borrowed_by' is equal to "nobody"(That means the book is not borrowed by anybody yet):
#         1. Print that "Yes, you can borrow this book.".
#         2. Change the variable 'self.borrowed_by' to be the studentName in the parameters. (That means the book is now borrowed by the student)
#     Else:
#         1. Print that "Someone else borrowed the book already, you cannot borrow the book.".
# ```
#
# #### A **📘function** called **'ReturnBook'**:
# 1. With the parameter **'(self)'**.
# 2. Read the **variable 'self.borrowed_by'**:
#    ```
#     If the variable 'self.borrowed_by' is equal to "nobody":
#         1. print that "The book hasn't been borrowed by anyone yet.".
#     else:
#         1. print that "You have returned the book successfully."
#         2. change the variable 'self.borrowed_by' to be "nobody". (That means the book is now returned not borrowed by anybody)
#    ```
#
# ### Milestone 2: Test your library to check if the book borrowing and returning functions work!
# 1. Create an **instance** for the **class 'Book'** (The book is called Harry Potter)
#
# 2. Write a line of code to let the program know that "Harry Potter" is borrowed by Alex. (🔑 Hint: Use the function BorrowBook() )
#
# 3. If now Harley tries to borrow Harry Potter, what the program will say? Print it out.
#
# 4. Write a line of code to let the program know that Alex returned the book. (🔑 Hint: Use the function ReturnBook() )

# %%
class Book:
    def __init__: 
        
        
        
    def BorrowBook:
        
        
    
    def ReturnBook:
